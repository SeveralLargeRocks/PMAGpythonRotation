# %%
import pmagpy.pmag as pmag
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import pmagpy.pmag as pmag 
import pmagpy.pmagplotlib as pmagplotlib
import pmagpy.ipmag as ipmag
from pmagpy import pmag, ipmag, pmagplotlib
from pathlib import Path                                                                                                                                                         
import math
import time as time
from statistics import mean,median
import seaborn as sns
# %matplotlib inline
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from _aux import (di2vgp,R_pole_space,P_pole_space,pseudo_DIs,get_resampled_sed_poles,get_pseudo_vgps,get_rotated_vgps,running_mean_APWP,get_reference_poles,get_pseudopoles)

# CHECK CARTOPY
has_cartopy, cartopy = pmag.import_cartopy()
if has_cartopy:
    print('Cartopy installed')
    import cartopy.crs as ccrs
    import cartopy.feature as cfeature

print("Import Complete")
# Out:
# Cartopy installed
# Import Complete

# %%
input_filename = "tec_data.csv"
df = pd.read_csv(input_filename,skiprows=0,header=0,skip_blank_lines=True) # build dataframe from Excel input file
df = df.reset_index(drop=True,inplace=False) # reset index of dataframe
N_poles = len(df)

# if age uncertainties are not given, use ±2 Ma 
df.min_age.fillna((df.age-2.), inplace=True)
df.max_age.fillna((df.age+2.), inplace=True)

# get pole latitudes and longitude
if 'mdec' in df:
    if len(df['mdec']) > 0: 
        mean_DIs = [[df['mdec'][i],df['minc'][i]] for i in range(N_poles)]
        samp_locs = [[df['slat'][i],df['slon'][i]] for i in range(N_poles)]
        paleopoles = di2vgp(di_block=mean_DIs,samp_loc=samp_locs)

    # add to dataframe
    poles_df = pd.DataFrame(paleopoles,columns=['plon','plat'])
    df['plat'] = poles_df['plat']
    df['plon'] = poles_df['plon']
    
    # get reference location from sampling locations
    locations = ipmag.make_di_block(df['slon'].tolist(),df['slat'].to_list())
    loc_princ = pmag.doprinc(locations)
    mean_loc = [loc_princ['dec'],loc_princ['inc']]
    print('Mean sampling location = ', mean_loc)

if 'P95' in df.columns:
    df['A95'] = df['P95']
    df['name'] = df.apply(lambda x: 'pole_at_%1d_Ma' % x['age'], axis=1)
    df['K'] = df['mean_K']
    # EXPORT TO FILE
df.to_csv('temp_tec.csv', index=None)
df = df.astype({'N':'int'})

print('Number of paleopoles =',N_poles)
# Out:
# Mean sampling location =  [np.float64(136.85629085097423), np.float64(36.23023583218624)]
# Number of paleopoles = 116

# %%
# Choose reference for computing displacements: 'gapwap', 'custom', 'geopole', 'refpole'
ref_type = 'gapwap'

# Get reference data
if ref_type =='gapwap':
    ref_filename = 'Global_APWP_DB_Vaes_et_al.xlsx'
    ref_df = pd.read_excel(ref_filename,skiprows=2,header=0,usecols='A:AB') # build dataframe from Excel input file
    # if K and A95 are unavailable, replace with estimated value from Cox (1970) formula
    ref_df.K.fillna(ref_df.K_est, inplace=True)
    ref_df.A95.fillna(ref_df.A95_est, inplace=True)
    # convert to northern hemisphere
    ref_df['plat'] = ref_df['plat'].apply(lambda x: x*-1)
    ref_df['plon'] = ref_df['plon'].apply(lambda x: x-180. % 360)
    
    ref_df = ref_df.astype({'N':'int'}) # ensure values for N are integers

    print('Reference datasets = ',len(ref_df))
    print(ref_df.head())

elif ref_type == 'custom':
    ref_filename = 'NEJ.csv'   # read database file
    ref_df = pd.read_csv(ref_filename,skiprows=0,header=0) # build dataframe from Excel input file
    # if age uncertainties are not given, use ±2 Ma 
    ref_df.min_age.fillna((ref_df.age-2.), inplace=True)
    ref_df.max_age.fillna((ref_df.age+2.), inplace=True)
    
    ref_df = ref_df.astype({'N':'int'}) # ensure values for N are integers

    print('Reference datasets = ',len(ref_df))
    print(ref_df.head())
elif ref_type == 'geopole':
    ref_pole = [0,90]
elif ref_type == 'refpole':
    ref_pole = [ref_plon,ref_plat]
    B95 = ref_A95 # is stored as B95 but is simply 95% confidence region of reference pole
# Out:
# Reference datasets =  350
#          name  min_age  max_age     age   slat    slon   N  mDec  mInc   k  \
# 0   Roperch15    0.000    0.005  0.0025 -38.91  288.26  18   NaN   NaN NaN
# 1  Dichiara14    0.002    0.008  0.0050  38.59  331.22  12   NaN   NaN NaN
# 2    Kissel15    0.000    0.015  0.0075  28.18  343.95  39   NaN   NaN NaN
# 3     Salis89    0.008    0.012  0.0100  45.52    2.81   6   NaN   NaN NaN
# 4    Tanaka09    0.000    0.021  0.0105 -38.16  176.50  13   NaN   NaN NaN
#
#    ...       Rlat        Rlon     EP_lat      EP_lon    EP_ang  lithology   f  \
# 0  ... -85.569348  162.837805  60.350000  -38.740000  0.000715    igneous NaN
# 1  ... -88.980260  146.929895  21.037123  -20.423398  0.000626    igneous NaN
# 2  ... -86.411049  329.646721   0.000000    0.000000  0.000000    igneous NaN
# 3  ... -87.192212   73.014943  21.037037  -20.422853  0.001252    igneous NaN
# 4  ... -88.852634   35.682249 -12.764688 -126.480273  0.006459    igneous NaN
#
#    p_std  Deenen  excl
# 0    NaN    True     0
# 1    NaN    True     0
# 2    NaN    True     0
# 3    NaN    True     0
# 4    NaN    True     0
#
# [5 rows x 28 columns]

# %%
### SETTINGS
Nb = 1000
ref_window = 10
ref_plate = 301

# CHOOSE REFERENCE LOCATION ('one_ref_loc', 'mean_loc', 'samp_loc')
ref_loc_type = 'samp_loc'
one_ref_loc = [140,39] # [lon,lat]

# GET EULER ROTATION POLES
if ref_type == 'gapwap':
    EP_data = np.genfromtxt('Euler_poles_%3d.csv' % ref_plate,skip_header=1,delimiter=',') # load csv file
else:
    EP_data = []

print("Settings loaded successfuly.")
# Out:
# Settings loaded successfuly.

# %%
# APPLY ALGORITHM TO EACH DATASET

# ---------

def calcRPD(df):
    N_poles=len(df)
    results=[]
    for i in range(N_poles):
        
        # GET KEY PARAMETERS
        name, age, min_age, max_age =df["name"][i], df["age"][i], df['min_age'][i],df['max_age'][i]
        N_s, min_age_test, max_age_test = df['N'][i],df['min_age'][i],df['max_age'][i]
        PP_lon, PP_lat, PP_A95 = df['plon'][i],df['plat'][i],df['A95'][i]
        
        # MODIFY REFERENCE DATA WINDOW
        if (max_age_test-min_age_test) < ref_window:
            max_age_test = df['age'][i]+(ref_window/2.)
            min_age_test = df['age'][i]-(ref_window/2.)
        
        # GET REFERENCE LOCATION
        if ref_loc_type == 'one_ref_loc':
            ref_loc = one_ref_loc
        elif ref_loc_type == 'mean_loc':
            ref_loc = mean_loc
        else:
            ref_loc = [df['slon'][i],df['slat'][i]]
            
        #print('')
        print('Entry number = %2d ; N = %1d, age range = %1.1f - %1.1f' % (i,N_s,min_age_test,max_age_test))
        
        # ------
        if ref_type == 'gapwap' or ref_type == 'custom':
            # GET PSEUDOPOLES    
            ppoles = []

            # SELECT PALEOPOLES FROM REFERENCE DATABASE
            df_ref_poles = ref_df[(ref_df.min_age <= max_age_test) & (ref_df.max_age >= min_age_test)].copy()
            df_ref_poles.reset_index()

            # GET PSEUDOPOLES
            ppoles = [get_pseudopoles(df=df_ref_poles,age_min=min_age_test,age_max=max_age_test,N_s=N_s,EP_data=EP_data) for k in range(Nb)]

            # COMPUTE REFERENCE POLE AND DIRECTION
            ppoles_mean = pmag.fisher_mean(ppoles) # compute mean of pseudopoles
            ref_pole = [ppoles_mean['dec'],ppoles_mean['inc']] # store reference mean

            # COMPUTE ANGULAR DISTANCE OF PSEUDOPOLES TO REFERENCE MEAN
            D_ppoles=[]
            for j in range(Nb):
                ang_distance=pmag.angle(ppoles[j],ref_pole)
                D_ppoles.append(ang_distance[0])

            # COMPUTE STATISTICS
            D_ppoles.sort() # sort angular distances to mean pole
            ind_95perc=int(0.95*Nb)-1 # find index of 95% percentile
            B95 = D_ppoles[ind_95perc] # get B95
            
            ref_N_values = [pseudopole[2] for pseudopole in ppoles]
            ref_N_mean = np.mean(ref_N_values) # compute mean N of simulated reference poles
            ref_K_values = [pseudopole[3] for pseudopole in ppoles]
            ref_K_mean = np.mean(ref_K_values) # compute mean K of simulated reference poles
            
        elif ref_type == 'geopole' or ref_type == 'refpole':
            ppoles_mean = {'dec': ref_pole[0], 'inc': ref_pole[1]}
            B95 = 0
            ref_N_mean = 0
            ref_K_mean = 0
            
        # ---------------
        # compute rotation in pole-space
        R,dr = R_pole_space(ref_pole,B95,[PP_lon,PP_lat],PP_A95,ref_loc)

        if R-dr>0 or R+dr<0: # check if lower confidence limit of rotation is larger than zero
            RS = True
        else:
            RS = False

        if 'EI_unc_plat' in df:
            if df['EI_unc_plat'][i]>0:
                PP_A95 = df['EI_unc_plat'][i]

        P,dp = P_pole_space(ref_pole,B95,[PP_lon,PP_lat],PP_A95,ref_loc)
        L = P*-1
        dl = dp

        if P-dp>0 or P+dp<0: # check if lower confidence limit of rotation is larger than zero
            LS = True
        else:
            LS = False

        ref_DI = pmag.vgp_di(ref_pole[1],ref_pole[0],ref_loc[1],ref_loc[0]) # compute reference direction

        # Append the result
        results.append({
            "name": name,
            "age": age, "max_age":max_age, "min_age": min_age, "N":N_poles,
            "R": R, "delta_R": dr, "R_sig": RS, 
            "L": L, "delta_L": dl, "L_sig": LS,
            "B95": B95, "A95": PP_A95,
            "plat": ppoles_mean['inc'], "plon": ppoles_mean['dec'], 
            "slat": ref_loc[1], "slon": ref_loc[0],
            "ref_dec": ref_DI[0], "ref_inc": ref_DI[1],
            "ref_mean_N": ref_N_mean, "ref_mean_K": ref_K_mean})

    print ("Done!")
    return results

results = pd.DataFrame(calcRPD(df))


###NOTE EDIT PATH TO YOUR DATA
results_path_1=Path("c:/Users/bruno/Desktop/japan/Script/rotations.csv")
results_path_2=Path("c:/Users/bruno/Desktop/japan/Script_auxiliary/results.csv")

results.to_csv(results_path_1, index=False)
results.to_csv(results_path_2, index=False)
# Out:
# Entry number =  0 ; N = 22, age range = -1.0 - 9.0
# Entry number =  1 ; N = 64, age range = -1.1 - 8.9
# Entry number =  2 ; N = 107, age range = -0.8 - 9.2
# Entry number =  3 ; N = 24, age range = -0.2 - 9.8
# Entry number =  4 ; N = 64, age range = 2.0 - 12.0
# Entry number =  5 ; N = 104, age range = 3.2 - 13.2
# Entry number =  6 ; N = 103, age range = 8.8 - 18.8
# Entry number =  7 ; N = 64, age range = 9.7 - 19.7
# Entry number =  8 ; N = 125, age range = 11.3 - 21.3
# Entry number =  9 ; N = 28, age range = 16.5 - 26.5
# Entry number = 10 ; N = 30, age range = 19.0 - 34.0
# Entry number = 11 ; N = 52, age range = 25.0 - 35.0
# Entry number = 12 ; N = 31, age range = 76.0 - 97.0
# Entry number = 13 ; N = 64, age range = 85.0 - 95.0
# Entry number = 14 ; N = 10, age range = 85.0 - 95.0
# Entry number = 15 ; N = 120, age range = 93.9 - 113.0
# Entry number = 16 ; N = 12, age range = 6.3 - 16.3
# Entry number = 17 ; N = 10, age range = 6.3 - 16.3
# Entry number = 18 ; N = 8, age range = 7.3 - 17.3
# Entry number = 19 ; N = 44, age range = 7.0 - 17.0
# Entry number = 20 ; N = 200, age range = 9.2 - 19.2
# Entry number = 21 ; N = 12, age range = 9.5 - 19.5
# Entry number = 22 ; N = 67, age range = 10.0 - 20.0
# Entry number = 23 ; N = 10, age range = 10.2 - 20.2
# Entry number = 24 ; N = 148, age range = 10.0 - 20.0
# Entry number = 25 ; N = 62, age range = 10.3 - 20.3
# Entry number = 26 ; N = 35, age range = 10.5 - 20.5
# Entry number = 27 ; N = 12, age range = 10.5 - 20.5
# Entry number = 28 ; N = 142, age range = 10.8 - 20.8
# Entry number = 29 ; N = 78, age range = 10.8 - 20.8
# Entry number = 30 ; N = 93, age range = 11.4 - 21.4
# Entry number = 31 ; N = 35, age range = 10.6 - 20.6
# Entry number = 32 ; N = 35, age range = 11.9 - 21.9
# Entry number = 33 ; N = 31, age range = 11.8 - 21.8
# Entry number = 34 ; N = 84, age range = 11.6 - 21.6
# Entry number = 35 ; N = 57, age range = 11.0 - 23.0
# Entry number = 36 ; N = 8, age range = 11.0 - 23.0
# Entry number = 37 ; N = 8, age range = 12.7 - 22.7
# Entry number = 38 ; N = 104, age range = 12.8 - 22.8
# Entry number = 39 ; N = 9, age range = 15.9 - 25.9
# Entry number = 40 ; N = 7, age range = 15.9 - 25.9
# Entry number = 41 ; N = 65, age range = 17.0 - 27.0
# Entry number = 42 ; N = 68, age range = 23.0 - 33.0
# Entry number = 43 ; N = 10, age range = 23.5 - 33.5
# Entry number = 44 ; N = 11, age range = 23.5 - 33.5
# Entry number = 45 ; N = 203, age range = 27.5 - 37.5
# Entry number = 46 ; N = 148, age range = 55.5 - 65.5
# Entry number = 47 ; N = 25, age range = 67.1 - 77.1
# Entry number = 48 ; N = 110, age range = 65.0 - 83.0
# Entry number = 49 ; N = 154, age range = 80.0 - 92.0
# Entry number = 50 ; N = 231, age range = 58.0 - 112.0
# Entry number = 51 ; N = 90, age range = 83.0 - 120.0
# Entry number = 52 ; N = 8, age range = 12.4 - 22.4
# Entry number = 53 ; N = 33, age range = 12.5 - 22.5
# Entry number = 54 ; N = 8, age range = 12.5 - 22.5
# Entry number = 55 ; N = 28, age range = 107.1 - 117.1
# Entry number = 56 ; N = 11, age range = 101.3 - 111.3
# Entry number = 57 ; N = 12, age range = 20.0 - 70.0
# Entry number = 58 ; N = 53, age range = -3.6 - 6.4
# Entry number = 59 ; N = 92, age range = -3.8 - 6.2
# Entry number = 60 ; N = 19, age range = -2.9 - 7.1
# Entry number = 61 ; N = 12, age range = -2.9 - 7.1
# Entry number = 62 ; N = 29, age range = 0.3 - 10.3
# Entry number = 63 ; N = 91, age range = 0.9 - 10.9
# Entry number = 64 ; N = 134, age range = 2.0 - 12.0
# Entry number = 65 ; N = 222, age range = 3.3 - 13.3
# Entry number = 66 ; N = 220, age range = 3.0 - 12.9
# Entry number = 67 ; N = 187, age range = 3.4 - 13.4
# Entry number = 68 ; N = 53, age range = 14.5 - 24.5
# Entry number = 69 ; N = 129, age range = -2.8 - 7.2
# Entry number = 70 ; N = 64, age range = 3.0 - 13.0
# Entry number = 71 ; N = 12, age range = 6.6 - 16.6
# Entry number = 72 ; N = 8, age range = 8.5 - 18.5
# Entry number = 73 ; N = 10, age range = 9.1 - 19.1
# Entry number = 74 ; N = 117, age range = 9.4 - 19.4
# Entry number = 75 ; N = 85, age range = 8.8 - 18.8
# Entry number = 76 ; N = 10, age range = 11.0 - 21.0
# Entry number = 77 ; N = 9, age range = 11.0 - 21.0
# Entry number = 78 ; N = 106, age range = 10.9 - 20.9
# Entry number = 79 ; N = 51, age range = 10.8 - 20.8
# Entry number = 80 ; N = 57, age range = 11.4 - 21.4
# Entry number = 81 ; N = 136, age range = 11.5 - 21.5
# Entry number = 82 ; N = 66, age range = 11.7 - 21.7
# Entry number = 83 ; N = 36, age range = 12.4 - 22.4
# Entry number = 84 ; N = 13, age range = 12.2 - 22.2
# Entry number = 85 ; N = 212, age range = 12.7 - 22.7
# Entry number = 86 ; N = 8, age range = 13.0 - 23.0
# Entry number = 87 ; N = 127, age range = 13.4 - 23.4
# Entry number = 88 ; N = 31, age range = 15.1 - 25.1
# Entry number = 89 ; N = 12, age range = 14.5 - 24.5
# Entry number = 90 ; N = 10, age range = 16.8 - 26.8
# Entry number = 91 ; N = 68, age range = 16.0 - 27.9
# Entry number = 92 ; N = 13, age range = 17.6 - 27.6
# Entry number = 93 ; N = 40, age range = 16.0 - 31.8
# Entry number = 94 ; N = 53, age range = 20.0 - 30.0
# Entry number = 95 ; N = 28, age range = 28.0 - 38.0
# Entry number = 96 ; N = 190, age range = 16.0 - 62.0
# Entry number = 97 ; N = 311, age range = 91.5 - 110.0
# Entry number = 98 ; N = 14, age range = 45.0 - 55.0
# Entry number = 99 ; N = 18, age range = 45.0 - 55.0
# Entry number = 100 ; N = 42, age range = 11.0 - 21.0
# Entry number = 101 ; N = 8, age range = 45.0 - 55.0
# Entry number = 102 ; N = 40, age range = 80.0 - 90.0
# Entry number = 103 ; N = 15, age range = 11.9 - 21.9
# Entry number = 104 ; N = 15, age range = 12.5 - 22.5
# Entry number = 105 ; N = 4, age range = 11.8 - 21.8
# Entry number = 106 ; N = 16, age range = 11.8 - 21.8
# Entry number = 107 ; N = 9, age range = 80.0 - 90.0
# Entry number = 108 ; N = 45, age range = -2.2 - 7.8
# Entry number = 109 ; N = 5, age range = 10.0 - 20.0
# Entry number = 110 ; N = 14, age range = 10.9 - 20.9
# Entry number = 111 ; N = 8, age range = 15.2 - 25.2
# Entry number = 112 ; N = 42, age range = 20.5 - 30.5
# Entry number = 113 ; N = 17, age range = 26.5 - 36.5
# Entry number = 114 ; N = 41, age range = 31.0 - 41.0
# Entry number = 115 ; N = 6, age range = 35.4 - 45.4
# Done!
