# %%
#Import libraries

import pandas as pd
import geopandas as gpd
import matplotlib as plt
from pathlib import Path
import folium
import math
import time
import sys
import geopy
import numpy as np
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster, PolyLineTextPath
from shapely.geometry import MultiPolygon
from shapely.ops import split, unary_union
from statistics import mean,median
from pmagpy import pmag

#import curator_aux as aux
from cur_calc_plot.curator_aux_magic import import_data, curator, pole_and_rotation_export, drop_overrepresented_locations
import importlib

print("Import complete")
# Out:
# Import complete

# %%
# %load_ext autoreload
# %autoreload 2

# %%
input_file = r'C:\Users\rosso\Documents\PMAGpython\data\SouthernAfricaPalaoemag Dataset.csv'
output_file = input_file

# with open(input_file, "r", encoding="utf-8") as f:
#     text = f.read()

# text_no_commas = text.replace(",", "")

# with open(output_file, "w", encoding="utf-8") as f:
#     f.write(text_no_commas)

# %%
#Settings for data cleaning

#Min number of samples needed?
num_min_samples = 4

#Only use the 
location_average = False

#Location removal threshold? (Min number of repeat locations needed for removal of all from dataset)
location_removal_threshold = 100000

#Calculate missing A95 values with K values and vice versa?
estimate_missing_a95_k = True

#Fill missing N values with N_alt values?
fill_sites = True

#Custom map needed? (Overrides default magic mapping)
custom_map_needed = True

#Custom mapping

custom_map={
    "nSample": "N",
    "Slat": "slat",
    "Slon": "slon",
    "k": "k",
    "a95": "a95",
    "Dec": "mdec",
    "Inc": "minc",
    "Geologic Area": "loc",
    "AgeLowBound": "AgeLowBound",
    "AgeUpBound": "AgeUpBound",
    "Name": "name",
    "Ref": "Ref",
    "A95_VGP": "A95",
    "K_VGP": "K"
}

# custom_map = {
#             "dir_n_samples": "N",
#             "lat": "slat",
#             "lon": "slon",
#             "dir_k": "k",
#             "dir_alpha95": "a95",
#             "dir_dec": "mdec",
#             "dir_inc": "minc",
#             "location": "loc",
#             "site_alternatives": "nSites",
#             "age_low": "AgeUpBound",
#             "age_high": "AgeLowBound",
#             "site": "name",
#             "citations": "Ref",
#             "vgp_alpha95": "A95",
#             "vgp_k": "K",
#             "dir_n_total_samples": "N_alt"
            
#         }

#df_raw =pd.read_csv(input_file,sep='\t',header=5)

path=r"C:\Users\rosso\Documents\PMAGpython\data\rawdata.csv"
#df_raw.to_csv(path, index=False)
# df = df[df['dir_n_samples'] >= num_min_samples]

# %%
### CURATE THE DATA
data_path=r"C:\Users\rosso\Documents\PMAGpython\data\SouthernAfricaPalaoemag Dataset.csv"
df=import_data(data_path)

#df = df_raw.copy()

f1=r"C:\Users\rosso\Documents\PMAGpython\data\tec_c.csv"
f2=r"C:\Users\rosso\Documents\PMAGpython\data\tec_c2.csv"

df["Primary"] = "Y"

df["Collection"] = ""

tec_data=curator(df,
                 num_min_samples,
                 location_average,
                 location_removal_threshold,
                 estimate_missing_a95_k,
                 fill_sites,
                 custom_map_needed,
                 custom_map)

pole_and_rotation_export(tec_data,f1,f2)
# Out:
# Added 'age' column.
# Before translator: (23, 32)
# 'age' column already exists.
# Added 'pole_k' column.
# Before polarity: (23, 33)
# Nr. of sites with normal polarity: 10
# Nr. of sites with reverse polarity: 13
# Number of rows converted to normal polarity: 13
# Before age curation: (23, 34)
# Before cleaning: (19, 37)
# Dropping rows with missing a95 and k (19, 37)
# Estimating missing A95 and K values (19, 37)
# 19 rows remain after estimating a95 or k values.
# Added 'N_alt' column.
# Dropping num_min_samples < 4 (19, 38)
# 19 rows remain after dropping rows with N < 4
# Dropping overrepresented locations with threshold > 100000
# Number of unique locations before removal: 19
# Averaging locations (19, 38)
# Dropping rows without a95 or k values
# Final cleaning complete. Remaining rows: 19
# Data curated successfully. Please use the Calculator script to obtain rotation data before plotting.
